# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter

# %%
final_2000 = "Data/final_tmdb_data_2000.csv.gz"
df_2000 = pd.read_csv(final_2000)
df_2000.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres  \
# 0         NaN                                                NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                homepage        id original_language  \
# ...

# %%
df_2000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1205 entries, 0 to 1204
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                1205 non-null   object
#  1   adult                  1204 non-null   float64
#  2   backdrop_path          634 non-null    object
#  3   belongs_to_collection  111 non-null    object
#  4   budget                 1204 non-null   float64
#  5   genres                 1204 non-null   object
#  6   homepage               66 non-null     object
#  7   id                     1204 non-null   float64
#  8   original_language      1204 non-null   object
#  9   original_title         1204 non-null   object
#  10  overview               1180 non-null   object
#  11  popularity             1204 non-null   float64
#  12  poster_path            1064 non-null   object
#  13  production_companies   1204 non-null   object
# ...

# %%
final_2001 = "Data/final_tmdb_data_2001.csv.gz"
df_2001 = pd.read_csv(final_2001)
df_2001.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /ab5yL8zgRotrICzGbEl10z24N71.jpg                   NaN
# 2  tt0114447    0.0                               NaN                   NaN
# 3  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg                   NaN
# 4  tt0118652    0.0  /mWxJEFRMvkG4UItYJkRDMgWQ08Y.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  48000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...      NaN
# 2         0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN
# 3  22000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN
# 4   1000000.0  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...      NaN
#
# ...

# %%
df_2001.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1288 entries, 0 to 1287
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                1288 non-null   object
#  1   adult                  1287 non-null   float64
#  2   backdrop_path          656 non-null    object
#  3   belongs_to_collection  86 non-null     object
#  4   budget                 1287 non-null   float64
#  5   genres                 1287 non-null   object
#  6   homepage               108 non-null    object
#  7   id                     1287 non-null   float64
#  8   original_language      1287 non-null   object
#  9   original_title         1287 non-null   object
#  10  overview               1259 non-null   object
#  11  popularity             1287 non-null   float64
#  12  poster_path            1133 non-null   object
#  13  production_companies   1287 non-null   object
# ...

# %%
frames = [df_2000, df_2001]
new_df = pd.concat(frames)
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2493 entries, 0 to 1287
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                2493 non-null   object
#  1   adult                  2491 non-null   float64
#  2   backdrop_path          1290 non-null   object
#  3   belongs_to_collection  197 non-null    object
#  4   budget                 2491 non-null   float64
#  5   genres                 2491 non-null   object
#  6   homepage               174 non-null    object
#  7   id                     2491 non-null   float64
#  8   original_language      2491 non-null   object
#  9   original_title         2491 non-null   object
#  10  overview               2439 non-null   object
#  11  popularity             2491 non-null   float64
#  12  poster_path            2197 non-null   object
#  13  production_companies   2491 non-null   object
# ...

# %%
new_df.to_csv('Data/final_results_tmdb.csv.gz', compression='gzip',index=False)

# %%
new_df[["budget", "revenue"]] = new_df[["budget", "revenue"]].replace(0, np.nan)
new_df.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres  \
# 0         NaN                                                NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 2         NaN           [{'id': 878, 'name': 'Science Fiction'}]
# 3         NaN  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                homepage        id original_language  \
# ...

# %%
budget_filter = new_df["budget"] > 0.0
revenue_filter = new_df["revenue"] > 0.0

financials = new_df.loc[budget_filter | revenue_filter, :]
financials.head()
# Out:
#       imdb_id  adult                     backdrop_path  \
# 1   tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 4   tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# 6   tt0119273    0.0  /fClJrAmJQ90zg9gWnfHVYSMiDTv.jpg
# 10  tt0120263    0.0  /ynXVuylP8upazjz8lrqb1PEMkdR.jpg
# 11  tt0120467    0.0  /knok3mNReKqPTplnnqz7E4dd7mD.jpg
#
#                                 belongs_to_collection      budget  \
# 1                                                 NaN  10000000.0
# 4                                                 NaN    150000.0
# 6   {'id': 141086, 'name': 'Heavy Metal Collection...  15000000.0
# 10                                                NaN         NaN
# 11                                                NaN    120000.0
#
#                                                genres  \
# 1   [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 4   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 6   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# ...

# %%
financials.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 620 entries, 1 to 1268
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                620 non-null    object
#  1   adult                  620 non-null    float64
#  2   backdrop_path          518 non-null    object
#  3   belongs_to_collection  102 non-null    object
#  4   budget                 535 non-null    float64
#  5   genres                 620 non-null    object
#  6   homepage               80 non-null     object
#  7   id                     620 non-null    float64
#  8   original_language      620 non-null    object
#  9   original_title         620 non-null    object
#  10  overview               617 non-null    object
#  11  popularity             620 non-null    float64
#  12  poster_path            599 non-null    object
#  13  production_companies   620 non-null    object
# ...

# %%
fig, ax = plt.subplots(figsize=(10, 4))

ax = financials["certification"].value_counts().plot(kind = "bar")

plt.ylabel("Count", fontsize = 15, fontweight = "bold", labelpad = 20)
plt.xlabel("Rating", fontsize = 15, fontweight = "bold", labelpad = 20)

plt.xticks(rotation = 45);
plt.xticks(fontweight = "medium", fontsize = 15)

plt.yticks(fontweight = "medium", fontsize = 15)
plt.yticks(np.arange(0, 230, 20));

# %%
revenue = financials.groupby("certification", as_index = False)['revenue'].mean()
revenue.plot(kind = "bar", x = "certification", y = "revenue")

plt.ticklabel_format(axis = "y")

plt.ylabel("Average Revenue", fontsize = 15, fontweight = "bold", labelpad = 20)
plt.xlabel("Rating", fontsize = 15, fontweight = "bold", labelpad = 20)

plt.xticks(rotation = 45);
plt.xticks(fontweight = "medium", fontsize = 15)

plt.yticks(fontweight = "medium", fontsize = 15);

# %%
budget = financials.groupby("certification", as_index = False)["budget"].mean()
budget.plot(kind = "bar", x = "certification", y = "budget")

plt.ticklabel_format(axis = "y", style='plain')

plt.ylabel("Average Budget", fontsize = 15, fontweight = "bold", labelpad = 20)
plt.xlabel("Rating", fontsize = 15, fontweight = "bold", labelpad = 20)

plt.xticks(rotation = 45);
plt.xticks(fontweight = "medium", fontsize = 15)

plt.yticks(fontweight = "medium", fontsize = 15);
